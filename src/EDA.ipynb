# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("application_data.csv")
dataprev = pd.read_csv("previous_application.csv")

# %%
print(f'La dimención del conjunto de datos application_data es {data.shape}')
print(f'La dimención del conjunto de datos previous_application es {dataprev.shape}')
# Out:
# La dimención del conjunto de datos application_data es (307511, 122)
# La dimención del conjunto de datos previous_application es (1670214, 37)

# %%
data.describe().T
# Out:
#                                  count           mean            std           min            25%            50%            75%           max
# SK_ID_CURR                    307511.0  278180.518577  102790.175348  1.000020e+05  189145.500000  278202.000000  367142.500000  4.562550e+05
# TARGET                        307511.0       0.080729       0.272419  0.000000e+00       0.000000       0.000000       0.000000  1.000000e+00
# CNT_CHILDREN                  307511.0       0.417052       0.722121  0.000000e+00       0.000000       0.000000       1.000000  1.900000e+01
# AMT_INCOME_TOTAL              307511.0  168797.919297  237123.146279  2.565000e+04  112500.000000  147150.000000  202500.000000  1.170000e+08
# AMT_CREDIT                    307511.0  599025.999706  402490.776996  4.500000e+04  270000.000000  513531.000000  808650.000000  4.050000e+06
# ...

# %%
dataprev.describe().T
# Out:
#                                count          mean            std           min           25%           50%           75%          max
# SK_ID_PREV                 1670214.0  1.923089e+06  532597.958696  1.000001e+06  1.461857e+06  1.923110e+06  2.384280e+06  2845382.000
# SK_ID_CURR                 1670214.0  2.783572e+05  102814.823849  1.000010e+05  1.893290e+05  2.787145e+05  3.675140e+05   456255.000
# AMT_ANNUITY                1297979.0  1.595512e+04   14782.137335  0.000000e+00  6.321780e+03  1.125000e+04  2.065842e+04   418058.145
# AMT_APPLICATION            1670214.0  1.752339e+05  292779.762387  0.000000e+00  1.872000e+04  7.104600e+04  1.803600e+05  6905160.000
# AMT_CREDIT                 1670213.0  1.961140e+05  318574.616546  0.000000e+00  2.416050e+04  8.054100e+04  2.164185e+05  6905160.000
# AMT_DOWN_PAYMENT            774370.0  6.697402e+03   20921.495410 -9.000000e-01  0.000000e+00  1.638000e+03  7.740000e+03  3060045.000
# ...

# %%
null_data = pd.DataFrame((data.isnull().sum())*100/data.shape[0]).reset_index()
null_data.columns = ['Columnas' , 'Porcentaje_de_valores_nulos']

# %%
null_data_40 = null_data[null_data['Porcentaje_de_valores_nulos'] > 40]
null_data_40
# Out:
#                         Columnas  Porcentaje_de_valores_nulos
# 21                   OWN_CAR_AGE                    65.990810
# 41                  EXT_SOURCE_1                    56.381073
# 44                APARTMENTS_AVG                    50.749729
# 45              BASEMENTAREA_AVG                    58.515956
# 46   YEARS_BEGINEXPLUATATION_AVG                    48.781019
# 47               YEARS_BUILD_AVG                    66.497784
# 48                COMMONAREA_AVG                    69.872297
# 49                 ELEVATORS_AVG                    53.295980
# 50                 ENTRANCES_AVG                    50.348768
# 51                 FLOORSMAX_AVG                    49.760822
# 52                 FLOORSMIN_AVG                    67.848630
# 53                  LANDAREA_AVG                    59.376738
# 54          LIVINGAPARTMENTS_AVG                    68.354953
# 55                LIVINGAREA_AVG                    50.193326
# ...

# %%
fig = plt.figure(figsize=(18,6))
ax = sns.pointplot(x="Columnas" , y="Porcentaje_de_valores_nulos" , data = null_data , color='green')
plt.xticks(rotation=90,fontsize=7)
ax.axhline(40, ls='--',color='red')
plt.title("Porcentaje de valores nulos en application data")
plt.ylabel("Porcentaje de valores nulos")
plt.xlabel("Columnas")
plt.show()

# %%
null_data_prev = pd.DataFrame((dataprev.isnull().sum())*100/dataprev.shape[0]).reset_index()
null_data_prev.columns = ['Columnas' , 'Porcentaje_de_valores_nulos']

# %%
null_dataprev_40 = null_data_prev[null_data_prev['Porcentaje_de_valores_nulos'] > 40]
null_dataprev_40
# Out:
#                      Columnas  Porcentaje_de_valores_nulos
# 6            AMT_DOWN_PAYMENT                    53.636480
# 12          RATE_DOWN_PAYMENT                    53.636480
# 13      RATE_INTEREST_PRIMARY                    99.643698
# 14   RATE_INTEREST_PRIVILEGED                    99.643698
# 20            NAME_TYPE_SUITE                    49.119754
# 31         DAYS_FIRST_DRAWING                    40.298129
# 32             DAYS_FIRST_DUE                    40.298129
# 33  DAYS_LAST_DUE_1ST_VERSION                    40.298129
# 34              DAYS_LAST_DUE                    40.298129
# 35           DAYS_TERMINATION                    40.298129
# 36  NFLAG_INSURED_ON_APPROVAL                    40.298129

# %%
fig = plt.figure(figsize=(18,6))
ax = sns.pointplot(x="Columnas" , y="Porcentaje_de_valores_nulos" , data = null_data_prev , color='orange')
plt.xticks(rotation=90,fontsize=7)
ax.axhline(40, ls='--',color='red')
plt.title("Porcentaje de valores nulos en previous application")
plt.ylabel("Porcentaje_de_valores_nulos")
plt.xlabel("Columnas")
plt.show()
